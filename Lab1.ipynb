# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagra20075/ML_Refreshers/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# !pip install opendatasets
import opendatasets as od
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
od.download("https://www.kaggle.com/competitions/quora-question-pairs/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ku5hagra
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 309M/309M [00:01<00:00, 219MB/s]
# Extracting archive ./quora-question-pairs/quora-question-pairs.zip to ./quora-question-pairs

# %%
# !unzip "/content/quora-question-pairs/train.csv.zip"
# Out:
# Archive:  /content/quora-question-pairs/train.csv.zip
#   inflating: train.csv

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %%
df.drop(["id"],axis=1)
# Out:
#           qid1    qid2                                          question1  \
# 0            1       2  What is the step by step guide to invest in sh...
# 1            3       4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2            5       6  How can I increase the speed of my internet co...
# 3            7       8  Why am I mentally very lonely? How can I solve...
# 4            9      10  Which one dissolve in water quikly sugar, salt...
# ...        ...     ...                                                ...
# 404285  433578  379845  How many keywords are there in the Racket prog...
# 404286   18840  155606          Do you believe there is life after death?
# 404287  537928  537929                                  What is one coin?
# 404288  537930  537931  What is the approx annual cost of living while...
# 404289  537932  537933              What is like to have sex with cousin?
#
#                                                 question2  is_duplicate
# ...

# %%
df.sample(n=20,random_state=1)
# Out:
#             id    qid1    qid2  \
# 237030  237030   33086  348102
# 247341  247341   73272    8624
# 246425  246425  359482  359483
# 306985  306985    1357   47020
# 225863  225863  334315  334316
# 259303  259303    6304  375056
# 224788  224788   94113   46020
# 393492  393492   71478  374655
# 138567  138567  220610  220611
# 324595  324595  450715  450716
# 143846  143846  227811  227812
# 3177      3177    6298    6299
# 210211  210211  314700  314701
# 287216  287216   53971  358528
# 176405  176405  271413  271414
# 252527  252527   41824   29506
# 331069  331069  453482  116988
# 392879  392879   39658   35260
# 254276  254276  147376   14333
# 2394      2394    4759    4760
#
#                                                 question1  \
# 237030                How can I stop playing video games?
# 247341     Who is better Donald Trump or Hillary Clinton?
# 246425  What do you think is the chance that sometime ...
# ...

# %%
len(df)
# Out:
# 404290

# %%
df.describe()
# Out:
#                   id           qid1           qid2   is_duplicate
# count  404290.000000  404290.000000  404290.000000  404290.000000
# mean   202144.500000  217243.942418  220955.655337       0.369198
# std    116708.614503  157751.700002  159903.182629       0.482588
# min         0.000000       1.000000       2.000000       0.000000
# 25%    101072.250000   74437.500000   74727.000000       0.000000
# 50%    202144.500000  192182.000000  197052.000000       0.000000
# 75%    303216.750000  346573.500000  354692.500000       1.000000
# max    404289.000000  537932.000000  537933.000000       1.000000

# %%
df.dropna()
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %%
df["is_duplicate"].value_counts()
# Out:
# 0    255027
# 1    149263
# Name: is_duplicate, dtype: int64

# %%
df["is_duplicate"].value_counts().plot.bar()

# %%
pd.concat([df['qid1'],df['qid2']]).value_counts()
# Out:
# 2559      157
# 30782     120
# 4044      111
# 2561       88
# 14376      79
#          ...
# 416446      1
# 416444      1
# 416441      1
# 416439      1
# 537933      1
# Length: 537933, dtype: int64

# %%
pd.concat([df['qid1'],df['qid2']]).value_counts().plot(logy=True,logx=True)
